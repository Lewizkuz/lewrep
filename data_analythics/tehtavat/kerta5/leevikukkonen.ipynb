# %% [markdown]
# # Kerran 5 Tehtävät

# %% [markdown]
# ### Leevi Kukkonen K8397

# %% [markdown]
# ## Tehtävä 1

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Tehtävä 2

# %%
import numpy as np
import pandas as pd
# T2
df = pd.read_csv('https://student.labranet.jamk.fi/~varpe/datananalk2019/kerta4/kysely.csv')

#  tjohto/sukupuoli jakauma
pd.crosstab(df['sukup'], df['Tjohto'])
df
# Out:
#     nro   sukup  ikä         perhe  koulutus  palveluv  Tjohto  Ttyöteht  \
# 0     1  nainen   38     perheetön       1.0      22.0       3         3
# 1     2  nainen   29  perheellinen       2.0      10.0       1         3
# 2     3    mies   30     perheetön       1.0       7.0       3         3
# 3     4    mies   36  perheellinen       1.0      14.0       3         3
# 4     5  nainen   24     perheetön       2.0       4.0       2         2
# 5     6    mies   31  perheellinen       2.0      14.0       4         4
# 6     7    mies   49     perheetön       2.0      16.0       3         2
# 7     8    mies   55     perheetön       1.0       0.0       3         3
# 8     9    mies   40  perheellinen       1.0      23.0       2         4
# 9    10    mies   33     perheetön       1.0      16.0       3         1
# 10   11  nainen   39  perheellinen       1.0      22.0       3         3
# 11   12    mies   40  perheellinen       3.0      21.0       3         2
# ...

# %%
import numpy as np
import pandas as pd
# prosenttiosuudet: koulutus, tyytyväisyys johtoon,
koulu = ({'perusasteen koulutus', 'keskiasteen koulutus', 'alempi korkeakoulutus', 'ylempi korkeakoulutus'})
pd.crosstab(df['koulutus'], df['Ttyöteht'], normalize='index').applymap("{:.1%}".format)
# Out:
# Ttyöteht      1      2      3      4      5
# koulutus
# 1.0       11.1%  11.1%  48.1%  22.2%   7.4%
# 2.0        3.3%  26.7%  33.3%  23.3%  13.3%
# 3.0        4.5%   9.1%  27.3%  54.5%   4.5%
# 4.0        0.0%  50.0%   0.0%   0.0%  50.0%

# %% [markdown]
# ## Tehtävä 3

# %%
#T3

# %% [markdown]
# ## Tehtävä 4

# %%
#T4

# %% [markdown]
# # Tehtävä 5
