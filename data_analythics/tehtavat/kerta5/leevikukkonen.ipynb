# %% [markdown]
# # Kerran 5 Tehtävät

# %% [markdown]
# ### Leevi Kukkonen K8397

# %% [markdown]
# ## Tehtävä 1

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
# lue arvot tiedostosta dataframeen
df = pd.read_csv('https://student.labranet.jamk.fi/~varpe/datananalk2019/kerta5/passatvariant.csv')
# käyttöönottovuosi, matkamittari ja CO2 -histogrammit
df['kayttoonottovuosi'].plot.hist()
plt.xlabel('ikä')
plt.show()
df['matkamittarilukema'].plot.hist()
plt.xlabel('Matkalukema')
plt.show()
df['Co2'].plot.hist()
plt.xlabel('Hiilipäästöt')
plt.show()

#käyttöönottovuosi, auton pituus, massa ja CO2
sns.jointplot('kayttoonottovuosi', 'ajonKokPituus', data=df, kind='reg')
plt.show()

# %% [markdown]
# ## Tehtävä 2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


x = np.linspace(-1,7,1000)
y1 =  2*x +1
y2 = 0.2*x**2-3
y3 = (x+1)**0.5
fig, ax = plt.subplots()
plt.grid(b=True, which='major', axis='both', linewidth=1, linestyle='--', color = 'green')
plt.tick_params(axis='both')
plt.figtext(0.5, 0.4, 'leikkauspiste')
plt.xticks(np.arange(-1, 10, 0.5))
plt.yticks(np.arange(-5,20, 1.0))
plt.axhline(y=0, xmin=10, xmax=0, color='black')
plt.axvline(x=0, ymin=10, ymax=0, color='black')
plt.plot(x, y1, linestyle='-.')
plt.plot(x, y2)
plt.plot(x, y3, linestyle='-.')

plt.show()

# %%
# Out:
# Ttyöteht      1      2      3      4      5
# koulutus
# 1.0       11.1%  11.1%  48.1%  22.2%   7.4%
# 2.0        3.3%  26.7%  33.3%  23.3%  13.3%
# 3.0        4.5%   9.1%  27.3%  54.5%   4.5%
# 4.0        0.0%  50.0%   0.0%   0.0%  50.0%

# %% [markdown]
# ## Tehtävä 3

# %%
#T3

# %% [markdown]
# ## Tehtävä 4

# %%
#T4

# %% [markdown]
# # Tehtävä 5
