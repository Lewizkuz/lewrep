# %% [markdown]
# # Kerran 4 Tehtävät

# %% [markdown]
# ### Leevi Kukkonen K8397

# %% [markdown]
# ## Tehtävä 1

# %%
import numpy as np
import pandas as pd

# T1
#df1 = pd.read_csv('https://student.labranet.jamk.fi/~varpe/datananalk2019/kerta4/pyörä.csv')
df2 = pd.read_csv('https://student.labranet.jamk.fi/~varpe/datananalk2019/kerta4/espoo.csv')
#df1
df3 = pd.merge(df1, df2)
print(df3())
# Out:
#       Vuosi  Kk  Pv    Klo Aikavyöhyke  Sateen intensiteetti (mm/h)  \
# 0      2016   6   1   0:00         UTC                          0.0
# 1      2016   6   1   1:00         UTC                          0.0
# 2      2016   6   1   2:00         UTC                          0.0
# 3      2016   6   1   3:00         UTC                          0.0
# 4      2016   6   1   4:00         UTC                          0.0
# 5      2016   6   1   5:00         UTC                          0.0
# 6      2016   6   1   6:00         UTC                          0.0
# 7      2016   6   1   7:00         UTC                          0.0
# 8      2016   6   1   8:00         UTC                          0.0
# 9      2016   6   1   9:00         UTC                          0.0
# 10     2016   6   1  10:00         UTC                          0.0
# 11     2016   6   1  11:00         UTC                          0.0
# 12     2016   6   1  12:00         UTC                          0.0
# ...

# %% [markdown]
# ## Tehtävä 2

# %%
# T2
df = pd.read_csv('https://student.labranet.jamk.fi/~varpe/datananalk2019/kerta4/kysely.csv')
print(pd.crosstab(df['sukup'], df['Tjohto']))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-2421e80519dd> in <module>
#       1 # T2
#       2 df = pd.read_csv('https://student.labranet.jamk.fi/~varpe/datananalk2019/kerta4/kysely.csv')
# ----> 3 print(df.crosstab(df['sukup'], df['Tjohto']))
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'crosstab'

# %% [markdown]
# ## Tehtävä 3

# %%
#T3
# Out:
# ['Etelä-Pohjanmaa' 'Pohjois-Pohjanmaa' 'Päijät-Häme' 'Uusimaa'
#  'Varsinais-Suomi' 'Pirkanmaa' 'Ahvenanmaa' 'Etelä-Savo' 'Lappi'
#  'Satakunta' 'Kanta-Häme' 'Keski-Pohjanmaa' 'Kymenlaakso' 'Keski-Suomi'
#  'Kainuu' 'Pohjois-Savo' 'Pohjois-Karjala' 'Pohjanmaa' 'Etelä-Karjala']
# Index(['Kunta-\nnumero', 'Kunta', 'Maakunta', 'Seutukunta', 'Kuntamuoto',
#        'Maapinta-ala\nkm2', 'Kokonaispinta-ala\nkm2', 'Väkiluku \n31.12.2015',
#        'Asukastiheys\nAsukkaita/km²', 'Asukastiheys\nAsukkaita/\nmaa-km²',
#        'Tuloveroprosentti 2016', 'Kielisuhde',
#        'Ruotsinkielisten osuus väestöstä, %',
#        'Korkea-asteen tutkinnon suorittaneiden osuus (yli 15-v.) %, 2014',
#        'Työttömien osuus työvoimasta, %, 2014'],
#       dtype='object')
# Kuntia (>50 000): 13
# Jykylän kunnat: 7
# Ruotsinkielisiä kuntia:  17
# Kunnat (vero% 19 < x < 20):  45

# %% [markdown]
# ## Tehtävä 4

# %%
#T4

# %% [markdown]
# # Tehtävä 5
