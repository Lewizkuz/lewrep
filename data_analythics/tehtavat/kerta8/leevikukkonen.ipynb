# %% [markdown]
# # Kerran 8 Tehtävät

# %% [markdown]
# ### Leevi Kukkonen K8397

# %% [markdown]
# ## Tehtävä 1

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

df = pd.read_csv('https://student.labranet.jamk.fi/~varpe/datananalk2019/kerta8/teht1.txt')
df
# Out:
#     as.luku    tuotto
# 0     61101  17.59200
# 1     55277   9.13020
# 2     85186  13.66200
# 3     70032  11.85400
# 4     58598   6.82330
# 5     83829  11.88600
# 6     74764   4.34830
# 7     85781  12.00000
# 8     64862   6.59870
# 9     50546   3.81660
# 10    57107   3.25220
# 11   141640  15.50500
# 12    57340   3.15510
# 13    84084   7.22580
# 14    56407   0.71618
# 15    53794   3.51290
# 16    63654   5.30480
# 17    51301   0.56077
# 18    64296   3.65180
# 19    70708   5.38930
# 20    61891   3.13860
# 21   202700  21.76700
# 22    54901   4.26300
# 23    63261   5.18750
# 24    55649   3.08250
# 25   189450  22.63800
# 26   128280  13.50100
# 27   109570   7.04670
# 28   131760  14.69200
# 29   222030  24.14700
# ..      ...       ...
# 67   102360   7.77540
# 68    54994   1.01730
# 69   203410  20.99200
# 70   101360   6.67990
# 71    73345   4.02590
# 72    60062   1.27840
# 73    72259   3.34110
# 74    50269  -2.68070
# 75    65479   0.29678
# ...

# %% [markdown]
# ## Tehtävä 2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime,  timedelta
df = pd.read_csv('http://student.labranet.jamk.fi/~varpe/datananalk2019/kerta6/kysely.txt' sep)
df
# Out:
#                                                  toimitusnopeus;hintataso;joustavuus hinnoissa;toimittajan imago;palvelu;myyntihenkilöstön imago;tuotteiden laatu;yleinen tyytyväisyys
# 4     1;0   6;6     9;4     7;2   4;2   3;5 2;4                                                2.0
# 1     8;3;6 3;6     6;2     5;4;8 4;4   3   NaN                                                NaN
# 3     4;5   2;5     7;6;4   3;2   7;8   2;5 2                                                  NaN
# 2     7;1;7 1;5     9;1     8;2   3;7   8;3 9                                                  NaN
# 6;0   9;9   6;7     8;3     4;4   6;4   5;6 8                                                  NaN
# 1     9;3   3;7     9;4     8;2   6;1   9;9 7;4                                                4.0
# 4     6;2   4;9     5;6     6;3   5;4   5;7 6;5                                                8.0
# 1     3;4   2;6     2;5     1;2   8;2   2;6 9;4                                                3.0
# ...

# %% [markdown]
# ## Tehtävä 3

# %%
#T3

# %% [markdown]
# ## Tehtävä 4

# %%
#T4

# %% [markdown]
# # Tehtävä 5
